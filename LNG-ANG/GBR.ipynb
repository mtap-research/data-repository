# %% [markdown]
# # Methane Working Capacity prediction using Machine Learning
#     1.1 Import package
#     1.2 Set variable
#     2.1 Divid dataset(Diversity Selection) and Save divided dataset
#     2.2 Load divided dataset
#     2.3 Plot feature distribution
#     3.1 Train model(Gradient Boosting Regression) and Save training model
#     3.2 Load feature importance from saved model
#     3.3 Plot feature importances
#
# ## Necessary Process 1.1, 1.2, 2.2, 3.2

# %% [markdown]
# ## 1.1 Import package

# %%
import random
import csv
import sys
import time
import math
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from os.path import expanduser
home = expanduser("~")

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from skopt.space import Real, Integer
from skopt.utils import use_named_args
from skopt import gp_minimize
#from sklearn.externals import joblib
import joblib
import pickle

# %% [markdown]
# ## 1.2  Set variable

# %%
file_name='Methane_merge_AGSA'
data_file_name="./"+file_name+".csv" 
feature_num=6
diverse_ratio=0.8 # training set ratio, 
remaining_ratio=1-diverse_ratio # test set ratio
random.seed(40)
cases=['LNG_ANG','ANG','5bar','6bar','65bar']

# %% [markdown]
# ## 2.1 Divid dataset (Diversity Selection) and Save divided dataset

# %%
with open(data_file_name) as f:
        data_file = csv.reader(f)
        temp = next(data_file)
        n_samples = int(temp[0])
        N_features = int(temp[1])
        if N_features != feature_num:
            print("N_features is not"+str(feature_num))
            sys.exit()
        data = np.empty((n_samples, N_features))
        temp = next(data_file)
        feature_list=temp[:N_features]
        for i, d in enumerate(data_file):
            data[i] = np.asarray(d[:feature_num], dtype=np.float64)
print("Total number of materials : ", data.shape[0])
N_materials = data.shape[0]


print("Number of features: ", N_features)
feature_0 = data.T[0]
feature_1 = data.T[1]
feature_2 = data.T[2]
feature_3 = data.T[3]
feature_4 = data.T[4]
feature_5 = data.T[5]
# rescale
feature_0 = (feature_0 - np.min(feature_0))/(np.max(feature_0) - np.min(feature_0))
feature_1 = (feature_1 - np.min(feature_1))/(np.max(feature_1) - np.min(feature_1))
feature_2 = (feature_2 - np.min(feature_2))/(np.max(feature_2) - np.min(feature_2))
feature_3 = (feature_3 - np.min(feature_3))/(np.max(feature_3) - np.min(feature_3))
feature_4 = (feature_4 - np.min(feature_4))/(np.max(feature_4) - np.min(feature_4))
feature_5 = (feature_5 - np.min(feature_5))/(np.max(feature_5) - np.min(feature_5))

if N_features == 5:
    x = np.concatenate((feature_0.reshape(1,N_materials),feature_1.reshape(1,N_materials),feature_2.reshape(1,N_materials),feature_3.reshape(1,N_materials),feature_4.reshape(1,N_materials)))
if N_features == 6:
    x = np.concatenate((feature_0.reshape(1,N_materials),feature_1.reshape(1,N_materials),feature_2.reshape(1,N_materials),feature_3.reshape(1,N_materials),feature_4.reshape(1,N_materials),feature_5.reshape(1,N_materials)))
if N_features == 7:
    x = np.concatenate((feature_0.reshape(1,N_materials),feature_1.reshape(1,N_materials),feature_2.reshape(1,N_materials),feature_3.reshape(1,N_materials),feature_4.reshape(1,N_materials),feature_5.reshape(1,N_materials),feature_6.reshape(1,N_materials)))
    
print("Shape of feature x: ", np.shape(x))
print("Example feature vector = " , x[:,0])
N_sample = int(N_materials * diverse_ratio)-1

print("Sampling %d diverse structures out of %d" % (N_sample+1,N_materials))
print("total accessible materials considered: ", N_materials)



print("Starting diversity selection. Seeking %d points" % (N_sample+1))
time.sleep(1)
# store indices of x here for the diverse and non-diverse sets.
diverse_set = []
remaining_set = list(range(N_materials))
# INITIALIZE WITH RANDOMLY SELECTED POINT
idx_init = random.sample(list(np.arange(N_materials)),1)[0]
diverse_set.append(idx_init)
remaining_set.remove(idx_init)
N_diverse = 1
while N_diverse <= N_sample:
        print("Selecting point ", N_diverse)
        min_d_to_diverse_set = np.zeros((N_materials-N_diverse,))
        # for every candidate point not in diverse set...
        for i in range(N_materials - N_diverse):
            # get the distance of this point to each point in the diverse set
            d_from_each_diverse_pt = np.linalg.norm(x[:,diverse_set] - x[:,remaining_set[i]].reshape(N_features,1),axis=0)
            # get the closest distance that this point is to the diverse set
            min_d_to_diverse_set[i] = np.min(d_from_each_diverse_pt)
        # select point that has the largest distance from the diverse set
        idx_select = remaining_set[np.argmax(min_d_to_diverse_set)]
        assert (len(remaining_set) == np.size(min_d_to_diverse_set))
        print("\tSelected point " , idx_select)
        # add point to diverse set; remove it from remaining set
        diverse_set.append(idx_select)
        remaining_set.remove(idx_select)
        print("\tPts in diverse set: ", len(diverse_set))
        print("\tPts in remaining set: ", len(remaining_set))
        print(diverse_set[N_diverse-1])
        N_diverse += 1

with open("divided_set_"+str(diverse_ratio)+"_"+str("%.1f" %(remaining_ratio))+"_"+str(feature_num)+"_"+file_name+"feature.txt", "w") as f:
    f.write(str(diverse_set)+" "+str(remaining_set))
    print("Save file name : divided_set_"+str(diverse_ratio)+"_"+str("%.1f" %(remaining_ratio))+"_"+str(N_features)+"_"+file_name+"feature.txt")
# Out:
# Total number of materials :  6374
# Number of features:  6
# Shape of feature x:  (6, 6374)
# Example feature vector =  [0.10930255 0.00874096 0.20207309 0.23267102 0.59577589 0.69222951]
# Sampling 5099 diverse structures out of 6374
# total accessible materials considered:  6374
# Starting diversity selection. Seeking 5099 points
# Selecting point  1
# 	Selected point  4374
# 	Pts in diverse set:  2
# 	Pts in remaining set:  6372
# 3756
# Selecting point  2
# 	Selected point  2694
# 	Pts in diverse set:  3
# 	Pts in remaining set:  6371
# 4374
# Selecting point  3
# 	Selected point  4866
# 	Pts in diverse set:  4
# 	Pts in remaining set:  6370
# 2694
# Selecting point  4
# 	Selected point  309
# 	Pts in diverse set:  5
# 	Pts in remaining set:  6369
# 4866
# Selecting point  5
# 	Selected point  207
# 	Pts in diverse set:  6
# 	Pts in remaining set:  6368
# 309
# Selecting point  6
# 	Selected point  3073
# 	Pts in diverse set:  7
# 	Pts in remaining set:  6367
# 207
# Selecting point  7
# 	Selected point  4372
# 	Pts in diverse set:  8
# 	Pts in remaining set:  6366
# 3073
# Selecting point  8
# 	Selected point  22
# 	Pts in diverse set:  9
# 	Pts in remaining set:  6365
# 4372
# Selecting point  9
# 	Selected point  33
# 	Pts in diverse set:  10
# 	Pts in remaining set:  6364
# 22
# Selecting point  10
# 	Selected point  52
# 	Pts in diverse set:  11
# 	Pts in remaining set:  6363
# 33
# Selecting point  11
# 	Selected point  4889
# 	Pts in diverse set:  12
# 	Pts in remaining set:  6362
# 52
# Selecting point  12
# 	Selected point  2423
# 	Pts in diverse set:  13
# 	Pts in remaining set:  6361
# 4889
# Selecting point  13
# 	Selected point  363
# 	Pts in diverse set:  14
# 	Pts in remaining set:  6360
# 2423
# Selecting point  14
# 	Selected point  2211
# 	Pts in diverse set:  15
# 	Pts in remaining set:  6359
# 363
# Selecting point  15
# 	Selected point  1398
# 	Pts in diverse set:  16
# 	Pts in remaining set:  6358
# 2211
# Selecting point  16
# 	Selected point  703
# 	Pts in diverse set:  17
# 	Pts in remaining set:  6357
# 1398
# Selecting point  17
# 	Selected point  4739
# 	Pts in diverse set:  18
# 	Pts in remaining set:  6356
# 703
# Selecting point  18
# 	Selected point  1455
# 	Pts in diverse set:  19
# 	Pts in remaining set:  6355
# 4739
# Selecting point  19
# 	Selected point  4373
# 	Pts in diverse set:  20
# 	Pts in remaining set:  6354
# 1455
# Selecting point  20
# 	Selected point  5638
# 	Pts in diverse set:  21
# 	Pts in remaining set:  6353
# 4373
# Selecting point  21
# 	Selected point  2318
# 	Pts in diverse set:  22
# 	Pts in remaining set:  6352
# 5638
# Selecting point  22
# 	Selected point  5732
# 	Pts in diverse set:  23
# 	Pts in remaining set:  6351
# 2318
# Selecting point  23
# 	Selected point  4227
# 	Pts in diverse set:  24
# 	Pts in remaining set:  6350
# 5732
# Selecting point  24
# 	Selected point  1416
# 	Pts in diverse set:  25
# 	Pts in remaining set:  6349
# 4227
# Selecting point  25
# 	Selected point  3821
# 	Pts in diverse set:  26
# 	Pts in remaining set:  6348
# 1416
# Selecting point  26
# 	Selected point  1198
# 	Pts in diverse set:  27
# 	Pts in remaining set:  6347
# 3821
# Selecting point  27
# 	Selected point  5760
# 	Pts in diverse set:  28
# 	Pts in remaining set:  6346
# 1198
# Selecting point  28
# 	Selected point  1612
# 	Pts in diverse set:  29
# 	Pts in remaining set:  6345
# 5760
# Selecting point  29
# 	Selected point  1651
# 	Pts in diverse set:  30
# 	Pts in remaining set:  6344
# 1612
# Selecting point  30
# 	Selected point  3639
# 	Pts in diverse set:  31
# 	Pts in remaining set:  6343
# 1651
# Selecting point  31
# 	Selected point  1099
# 	Pts in diverse set:  32
# 	Pts in remaining set:  6342
# 3639
# Selecting point  32
# 	Selected point  2971
# 	Pts in diverse set:  33
# 	Pts in remaining set:  6341
# 1099
# Selecting point  33
# 	Selected point  3286
# 	Pts in diverse set:  34
# 	Pts in remaining set:  6340
# 2971
# Selecting point  34
# 	Selected point  2483
# 	Pts in diverse set:  35
# 	Pts in remaining set:  6339
# 3286
# Selecting point  35
# 	Selected point  6037
# 	Pts in diverse set:  36
# 	Pts in remaining set:  6338
# 2483
# Selecting point  36
# 	Selected point  2419
# 	Pts in diverse set:  37
# 	Pts in remaining set:  6337
# 6037
# Selecting point  37
# 	Selected point  2750
# 	Pts in diverse set:  38
# 	Pts in remaining set:  6336
# 2419
# Selecting point  38
# 	Selected point  4946
# 	Pts in diverse set:  39
# 	Pts in remaining set:  6335
# 2750
# Selecting point  39
# 	Selected point  2475
# 	Pts in diverse set:  40
# 	Pts in remaining set:  6334
# 4946
# Selecting point  40
# 	Selected point  2509
# 	Pts in diverse set:  41
# 	Pts in remaining set:  6333
# 2475
# Selecting point  41
# 	Selected point  454
# 	Pts in diverse set:  42
# 	Pts in remaining set:  6332
# 2509
# Selecting point  42
# 	Selected point  2913
# 	Pts in diverse set:  43
# 	Pts in remaining set:  6331
# 454
# Selecting point  43
# 	Selected point  2582
# 	Pts in diverse set:  44
# 	Pts in remaining set:  6330
# 2913
# Selecting point  44
# 	Selected point  3028
# 	Pts in diverse set:  45
# 	Pts in remaining set:  6329
# 2582
# Selecting point  45
# 	Selected point  4662
# 	Pts in diverse set:  46
# 	Pts in remaining set:  6328
# 3028
# Selecting point  46
# 	Selected point  2239
# 	Pts in diverse set:  47
# 	Pts in remaining set:  6327
# 4662
# Selecting point  47
# 	Selected point  2741
# 	Pts in diverse set:  48
# 	Pts in remaining set:  6326
# 2239
# Selecting point  48
# 	Selected point  4191
# 	Pts in diverse set:  49
# 	Pts in remaining set:  6325
# 2741
# Selecting point  49
# 	Selected point  1635
# 	Pts in diverse set:  50
# 	Pts in remaining set:  6324
# 4191
# Selecting point  50
# 	Selected point  1445
# 	Pts in diverse set:  51
# 	Pts in remaining set:  6323
# 1635
# Selecting point  51
# 	Selected point  1553
# 	Pts in diverse set:  52
# 	Pts in remaining set:  6322
# 1445
# Selecting point  52
# 	Selected point  4969
# 	Pts in diverse set:  53
# 	Pts in remaining set:  6321
# 1553
# Selecting point  53
# 	Selected point  428
# 	Pts in diverse set:  54
# 	Pts in remaining set:  6320
# 4969
# Selecting point  54
# 	Selected point  3883
# 	Pts in diverse set:  55
# 	Pts in remaining set:  6319
# 428
# Selecting point  55
# 	Selected point  5809
# 	Pts in diverse set:  56
# 	Pts in remaining set:  6318
# 3883
# Selecting point  56
# 	Selected point  1059
# 	Pts in diverse set:  57
# 	Pts in remaining set:  6317
# 5809
# Selecting point  57
# 	Selected point  2843
# 	Pts in diverse set:  58
# 	Pts in remaining set:  6316
# 1059
# Selecting point  58
# 	Selected point  3916
# 	Pts in diverse set:  59
# 	Pts in remaining set:  6315
# 2843
# Selecting point  59
# 	Selected point  2679
# 	Pts in diverse set:  60
# 	Pts in remaining set:  6314
# 3916
# Selecting point  60
# 	Selected point  6184
# 	Pts in diverse set:  61
# 	Pts in remaining set:  6313
# 2679
# Selecting point  61
# 	Selected point  2632
# 	Pts in diverse set:  62
# 	Pts in remaining set:  6312
# 6184
# Selecting point  62
# 	Selected point  3300
# 	Pts in diverse set:  63
# 	Pts in remaining set:  6311
# 2632
# Selecting point  63
# 	Selected point  4006
# 	Pts in diverse set:  64
# 	Pts in remaining set:  6310
# 3300
# Selecting point  64
# 	Selected point  440
# 	Pts in diverse set:  65
# 	Pts in remaining set:  6309
# 4006
# Selecting point  65
# 	Selected point  3195
# 	Pts in diverse set:  66
# 	Pts in remaining set:  6308
# 440
# Selecting point  66
# 	Selected point  3452
# 	Pts in diverse set:  67
# 	Pts in remaining set:  6307
# 3195
# Selecting point  67
# 	Selected point  4126
# 	Pts in diverse set:  68
# 	Pts in remaining set:  6306
# 3452
# Selecting point  68
# 	Selected point  5324
# 	Pts in diverse set:  69
# 	Pts in remaining set:  6305
# 4126
# Selecting point  69
# 	Selected point  2315
# 	Pts in diverse set:  70
# 	Pts in remaining set:  6304
# 5324
# Selecting point  70
# 	Selected point  2693
# 	Pts in diverse set:  71
# 	Pts in remaining set:  6303
# 2315
# Selecting point  71
# 	Selected point  1676
# 	Pts in diverse set:  72
# 	Pts in remaining set:  6302
# 2693
# Selecting point  72
# 	Selected point  6024
# 	Pts in diverse set:  73
# 	Pts in remaining set:  6301
# 1676
# Selecting point  73
# 	Selected point  119
# 	Pts in diverse set:  74
# 	Pts in remaining set:  6300
# 6024
# Selecting point  74
# 	Selected point  3479
# 	Pts in diverse set:  75
# 	Pts in remaining set:  6299
# 119
# Selecting point  75
# 	Selected point  4995
# 	Pts in diverse set:  76
# 	Pts in remaining set:  6298
# 3479
# Selecting point  76
# 	Selected point  5920
# 	Pts in diverse set:  77
# 	Pts in remaining set:  6297
# 4995
# Selecting point  77
# 	Selected point  3320
# 	Pts in diverse set:  78
# 	Pts in remaining set:  6296
# 5920
# Selecting point  78
# 	Selected point  1200
# 	Pts in diverse set:  79
# 	Pts in remaining set:  6295
# 3320
# Selecting point  79
# 	Selected point  5966
# 	Pts in diverse set:  80
# 	Pts in remaining set:  6294
# 1200
# Selecting point  80
# 	Selected point  2809
# 	Pts in diverse set:  81
# 	Pts in remaining set:  6293
# 5966
# Selecting point  81
# 	Selected point  3940
# 	Pts in diverse set:  82
# 	Pts in remaining set:  6292
# 2809
# Selecting point  82
# 	Selected point  1581
# 	Pts in diverse set:  83
# 	Pts in remaining set:  6291
# 3940
# Selecting point  83
# 	Selected point  2608
# 	Pts in diverse set:  84
# 	Pts in remaining set:  6290
# 1581
# Selecting point  84
# 	Selected point  3451
# 	Pts in diverse set:  85
# 	Pts in remaining set:  6289
# 2608
# Selecting point  85
# 	Selected point  3266
# 	Pts in diverse set:  86
# 	Pts in remaining set:  6288
# 3451
# Selecting point  86
# 	Selected point  3083
# 	Pts in diverse set:  87
# 	Pts in remaining set:  6287
# 3266
# Selecting point  87
# 	Selected point  349
# 	Pts in diverse set:  88
# 	Pts in remaining set:  6286
# 3083
# Selecting point  88
# 	Selected point  5750
# 	Pts in diverse set:  89
# 	Pts in remaining set:  6285
# 349
# Selecting point  89
# 	Selected point  316
# 	Pts in diverse set:  90
# 	Pts in remaining set:  6284
# 5750
# Selecting point  90
# 	Selected point  2414
# 	Pts in diverse set:  91
# 	Pts in remaining set:  6283
# 316
# Selecting point  91
# 	Selected point  2045
# 	Pts in diverse set:  92
# 	Pts in remaining set:  6282
# 2414
# Selecting point  92
# 	Selected point  351
# 	Pts in diverse set:  93
# 	Pts in remaining set:  6281
# 2045
# Selecting point  93
# 	Selected point  1583
# 	Pts in diverse set:  94
# 	Pts in remaining set:  6280
# 351
# Selecting point  94
# 	Selected point  1173
# 	Pts in diverse set:  95
# 	Pts in remaining set:  6279
# 1583
# Selecting point  95
# 	Selected point  503
# 	Pts in diverse set:  96
# 	Pts in remaining set:  6278
# 1173
# Selecting point  96
# 	Selected point  2489
# 	Pts in diverse set:  97
# 	Pts in remaining set:  6277
# 503
# Selecting point  97
# 	Selected point  4056
# 	Pts in diverse set:  98
# 	Pts in remaining set:  6276
# 2489
# Selecting point  98
# 	Selected point  1781
# 	Pts in diverse set:  99
# 	Pts in remaining set:  6275
# 4056
# Selecting point  99
# 	Selected point  4074
# 	Pts in diverse set:  100
# 	Pts in remaining set:  6274
# 1781
# Selecting point  100
# 	Selected point  4148
# 	Pts in diverse set:  101
# 	Pts in remaining set:  6273
# 4074
# Selecting point  101
# 	Selected point  536
# 	Pts in diverse set:  102
# 	Pts in remaining set:  6272
# 4148
# Selecting point  102
# 	Selected point  6287
# 	Pts in diverse set:  103
# 	Pts in remaining set:  6271
# 536
# Selecting point  103
# 	Selected point  3475
# 	Pts in diverse set:  104
# 	Pts in remaining set:  6270
# 6287
# Selecting point  104
# 	Selected point  2440
# 	Pts in diverse set:  105
# 	Pts in remaining set:  6269
# 3475
# Selecting point  105
# 	Selected point  4225
# 	Pts in diverse set:  106
# 	Pts in remaining set:  6268
# 2440
# Selecting point  106
# 	Selected point  5023
# 	Pts in diverse set:  107
# 	Pts in remaining set:  6267
# 4225
# Selecting point  107
# 	Selected point  4206
# 	Pts in diverse set:  108
# 	Pts in remaining set:  6266
# 5023
# Selecting point  108
# 	Selected point  3599
# 	Pts in diverse set:  109
# 	Pts in remaining set:  6265
# 4206
# Selecting point  109
# 	Selected point  6007
# 	Pts in diverse set:  110
# 	Pts in remaining set:  6264
# 3599
# Selecting point  110
# 	Selected point  3484
# 	Pts in diverse set:  111
# 	Pts in remaining set:  6263
# 6007
# Selecting point  111
# 	Selected point  3782
# 	Pts in diverse set:  112
# 	Pts in remaining set:  6262
# 3484
# Selecting point  112
# 	Selected point  3112
# 	Pts in diverse set:  113
# 	Pts in remaining set:  6261
# 3782
# Selecting point  113
# 	Selected point  6254
# 	Pts in diverse set:  114
# 	Pts in remaining set:  6260
# 3112
# Selecting point  114
# 	Selected point  2364
# 	Pts in diverse set:  115
# 	Pts in remaining set:  6259
# 6254
# Selecting point  115
# 	Selected point  5422
# 	Pts in diverse set:  116
# 	Pts in remaining set:  6258
# 2364
# Selecting point  116
# 	Selected point  2085
# 	Pts in diverse set:  117
# 	Pts in remaining set:  6257
# 5422
# Selecting point  117
# 	Selected point  1284
# 	Pts in diverse set:  118
# 	Pts in remaining set:  6256
# 2085
# Selecting point  118
# 	Selected point  1227
# 	Pts in diverse set:  119
# 	Pts in remaining set:  6255
# 1284
# Selecting point  119
# 	Selected point  2357
# 	Pts in diverse set:  120
# 	Pts in remaining set:  6254
# 1227
# Selecting point  120
# 	Selected point  6113
# 	Pts in diverse set:  121
# 	Pts in remaining set:  6253
# 2357
# Selecting point  121
# 	Selected point  3798
# 	Pts in diverse set:  122
# 	Pts in remaining set:  6252
# 6113
# Selecting point  122
# 	Selected point  5382
# 	Pts in diverse set:  123
# 	Pts in remaining set:  6251
# 3798
# Selecting point  123
# 	Selected point  2008
# 	Pts in diverse set:  124
# 	Pts in remaining set:  6250
# 5382
# Selecting point  124
# 	Selected point  6348
# 	Pts in diverse set:  125
# 	Pts in remaining set:  6249
# 2008
# Selecting point  125
# 	Selected point  3285
# 	Pts in diverse set:  126
# 	Pts in remaining set:  6248
# 6348
# Selecting point  126
# 	Selected point  3651
# 	Pts in diverse set:  127
# 	Pts in remaining set:  6247
# 3285
# Selecting point  127
# 	Selected point  353
# 	Pts in diverse set:  128
# 	Pts in remaining set:  6246
# 3651
# Selecting point  128
# 	Selected point  6319
# 	Pts in diverse set:  129
# 	Pts in remaining set:  6245
# 353
# Selecting point  129
# 	Selected point  183
# 	Pts in diverse set:  130
# 	Pts in remaining set:  6244
# 6319
# Selecting point  130
# 	Selected point  1697
# 	Pts in diverse set:  131
# 	Pts in remaining set:  6243
# 183
# Selecting point  131
# 	Selected point  2731
# 	Pts in diverse set:  132
# 	Pts in remaining set:  6242
# 1697
# Selecting point  132
# 	Selected point  2402
# 	Pts in diverse set:  133
# 	Pts in remaining set:  6241
# 2731
# Selecting point  133
# 	Selected point  1103
# 	Pts in diverse set:  134
# 	Pts in remaining set:  6240
# 2402
# Selecting point  134
# 	Selected point  2145
# 	Pts in diverse set:  135
# 	Pts in remaining set:  6239
# 1103
# Selecting point  135
# 	Selected point  5497
# 	Pts in diverse set:  136
# 	Pts in remaining set:  6238
# 2145
# Selecting point  136
# 	Selected point  5025
# 	Pts in diverse set:  137
# 	Pts in remaining set:  6237
# 5497
# Selecting point  137
# 	Selected point  3754
# 	Pts in diverse set:  138
# 	Pts in remaining set:  6236
# 5025
# Selecting point  138
# 	Selected point  4195
# 	Pts in diverse set:  139
# 	Pts in remaining set:  6235
# 3754
# Selecting point  139
# 	Selected point  5307
# 	Pts in diverse set:  140
# 	Pts in remaining set:  6234
# 4195
# Selecting point  140
# 	Selected point  822
# 	Pts in diverse set:  141
# 	Pts in remaining set:  6233
# 5307
# Selecting point  141
# 	Selected point  4994
# 	Pts in diverse set:  142
# 	Pts in remaining set:  6232
# 822
# Selecting point  142
# 	Selected point  5018
# 	Pts in diverse set:  143
# 	Pts in remaining set:  6231
# 4994
# Selecting point  143
# 	Selected point  1473
# 	Pts in diverse set:  144
# 	Pts in remaining set:  6230
# 5018
# Selecting point  144
# 	Selected point  1093
# 	Pts in diverse set:  145
# 	Pts in remaining set:  6229
# 1473
# Selecting point  145
# 	Selected point  1921
# 	Pts in diverse set:  146
# 	Pts in remaining set:  6228
# 1093
# Selecting point  146
# 	Selected point  25
# 	Pts in diverse set:  147
# 	Pts in remaining set:  6227
# 1921
# Selecting point  147
# 	Selected point  2450
# 	Pts in diverse set:  148
# 	Pts in remaining set:  6226
# 25
# Selecting point  148
# 	Selected point  2882
# 	Pts in diverse set:  149
# 	Pts in remaining set:  6225
# 2450
# Selecting point  149
# 	Selected point  4343
# 	Pts in diverse set:  150
# 	Pts in remaining set:  6224
# 2882
# Selecting point  150
# 	Selected point  2572
# 	Pts in diverse set:  151
# 	Pts in remaining set:  6223
# 4343
# Selecting point  151
# 	Selected point  1802
# 	Pts in diverse set:  152
# 	Pts in remaining set:  6222
# 2572
# Selecting point  152
# 	Selected point  2488
# 	Pts in diverse set:  153
# 	Pts in remaining set:  6221
# 1802
# Selecting point  153
# 	Selected point  4208
# 	Pts in diverse set:  154
# 	Pts in remaining set:  6220
# 2488
# Selecting point  154
# 	Selected point  5890
# 	Pts in diverse set:  155
# 	Pts in remaining set:  6219
# 4208
# Selecting point  155
# 	Selected point  4337
# 	Pts in diverse set:  156
# 	Pts in remaining set:  6218
# 5890
# Selecting point  156
# 	Selected point  3725
# 	Pts in diverse set:  157
# 	Pts in remaining set:  6217
# 4337
# Selecting point  157
# 	Selected point  1160
# 	Pts in diverse set:  158
# 	Pts in remaining set:  6216
# 3725
# Selecting point  158
# 	Selected point  5922
# 	Pts in diverse set:  159
# 	Pts in remaining set:  6215
# 1160
# Selecting point  159
# 	Selected point  1270
# 	Pts in diverse set:  160
# 	Pts in remaining set:  6214
# 5922
# Selecting point  160
# 	Selected point  3115
# 	Pts in diverse set:  161
# 	Pts in remaining set:  6213
# 1270
# Selecting point  161
# 	Selected point  4898
# 	Pts in diverse set:  162
# 	Pts in remaining set:  6212
# 3115
# Selecting point  162
# 	Selected point  5674
# 	Pts in diverse set:  163
# 	Pts in remaining set:  6211
# 4898
# Selecting point  163
# 	Selected point  916
# 	Pts in diverse set:  164
# 	Pts in remaining set:  6210
# 5674
# Selecting point  164
# 	Selected point  5995
# 	Pts in diverse set:  165
# 	Pts in remaining set:  6209
# 916
# Selecting point  165
# 	Selected point  6091
# 	Pts in diverse set:  166
# 	Pts in remaining set:  6208
# 5995
# Selecting point  166
# 	Selected point  1799
# 	Pts in diverse set:  167
# 	Pts in remaining set:  6207
# 6091
# Selecting point  167
# 	Selected point  2903
# 	Pts in diverse set:  168
# 	Pts in remaining set:  6206
# 1799
# Selecting point  168
# 	Selected point  157
# 	Pts in diverse set:  169
# 	Pts in remaining set:  6205
# 2903
# Selecting point  169
# 	Selected point  1986
# 	Pts in diverse set:  170
# 	Pts in remaining set:  6204
# 157
# Selecting point  170
# 	Selected point  5709
# 	Pts in diverse set:  171
# 	Pts in remaining set:  6203
# 1986
# Selecting point  171
# 	Selected point  3362
# 	Pts in diverse set:  172
# 	Pts in remaining set:  6202
# 5709
# Selecting point  172
# 	Selected point  3204
# 	Pts in diverse set:  173
# 	Pts in remaining set:  6201
# 3362
# Selecting point  173
# 	Selected point  2487
# 	Pts in diverse set:  174
# 	Pts in remaining set:  6200
# 3204
# Selecting point  174
# 	Selected point  1947
# 	Pts in diverse set:  175
# 	Pts in remaining set:  6199
# 2487
# Selecting point  175
# 	Selected point  2086
# 	Pts in diverse set:  176
# 	Pts in remaining set:  6198
# 1947
# Selecting point  176
# 	Selected point  5273
# 	Pts in diverse set:  177
# 	Pts in remaining set:  6197
# 2086
# Selecting point  177
# 	Selected point  4367
# 	Pts in diverse set:  178
# 	Pts in remaining set:  6196
# 5273
# Selecting point  178
# 	Selected point  6134
# 	Pts in diverse set:  179
# 	Pts in remaining set:  6195
# 4367
# Selecting point  179
# 	Selected point  3775
# 	Pts in diverse set:  180
# 	Pts in remaining set:  6194
# 6134
# Selecting point  180
# 	Selected point  354
# 	Pts in diverse set:  181
# 	Pts in remaining set:  6193
# 3775
# Selecting point  181
# 	Selected point  1932
# 	Pts in diverse set:  182
# 	Pts in remaining set:  6192
# 354
# Selecting point  182
# 	Selected point  2781
# 	Pts in diverse set:  183
# 	Pts in remaining set:  6191
# 1932
# Selecting point  183
# 	Selected point  2362
# 	Pts in diverse set:  184
# 	Pts in remaining set:  6190
# 2781
# Selecting point  184
# 	Selected point  226
# 	Pts in diverse set:  185
# 	Pts in remaining set:  6189
# 2362
# Selecting point  185
# 	Selected point  566
# 	Pts in diverse set:  186
# 	Pts in remaining set:  6188
# 226
# Selecting point  186
# 	Selected point  4288
# 	Pts in diverse set:  187
# 	Pts in remaining set:  6187
# 566
# Selecting point  187
# 	Selected point  2471
# 	Pts in diverse set:  188
# 	Pts in remaining set:  6186
# 4288
# Selecting point  188
# 	Selected point  1694
# 	Pts in diverse set:  189
# 	Pts in remaining set:  6185
# 2471
# Selecting point  189
# 	Selected point  379
# 	Pts in diverse set:  190
# 	Pts in remaining set:  6184
# 1694
# Selecting point  190
# 	Selected point  4134
# 	Pts in diverse set:  191
# 	Pts in remaining set:  6183
# 379
# Selecting point  191
# 	Selected point  5987
# 	Pts in diverse set:  192
# 	Pts in remaining set:  6182
# 4134
# Selecting point  192
# 	Selected point  5883
# 	Pts in diverse set:  193
# 	Pts in remaining set:  6181
# 5987
# Selecting point  193
# 	Selected point  254
# 	Pts in diverse set:  194
# 	Pts in remaining set:  6180
# 5883
# Selecting point  194
# 	Selected point  6180
# 	Pts in diverse set:  195
# 	Pts in remaining set:  6179
# 254
# Selecting point  195
# 	Selected point  328
# 	Pts in diverse set:  196
# 	Pts in remaining set:  6178
# 6180
# Selecting point  196
# 	Selected point  889
# 	Pts in diverse set:  197
# 	Pts in remaining set:  6177
# 328
# Selecting point  197
# 	Selected point  5419
# 	Pts in diverse set:  198
# 	Pts in remaining set:  6176
# 889
# Selecting point  198
# 	Selected point  894
# 	Pts in diverse set:  199
# 	Pts in remaining set:  6175
# 5419
# Selecting point  199
# 	Selected point  2307
# 	Pts in diverse set:  200
# 	Pts in remaining set:  6174
# 894
# Selecting point  200
# 	Selected point  401
# 	Pts in diverse set:  201
# 	Pts in remaining set:  6173
# 2307
# Selecting point  201
# 	Selected point  3908
# 	Pts in diverse set:  202
# 	Pts in remaining set:  6172
# 401
# Selecting point  202
# 	Selected point  2782
# 	Pts in diverse set:  203
# 	Pts in remaining set:  6171
# 3908
# Selecting point  203
# 	Selected point  2132
# 	Pts in diverse set:  204
# 	Pts in remaining set:  6170
# 2782
# Selecting point  204
# 	Selected point  6157
# 	Pts in diverse set:  205
# 	Pts in remaining set:  6169
# 2132
# Selecting point  205
# 	Selected point  3160
# 	Pts in diverse set:  206
# 	Pts in remaining set:  6168
# 6157
# Selecting point  206
# 	Selected point  462
# 	Pts in diverse set:  207
# 	Pts in remaining set:  6167
# 3160
# Selecting point  207
# 	Selected point  3207
# 	Pts in diverse set:  208
# 	Pts in remaining set:  6166
# 462
# Selecting point  208
# 	Selected point  3476
# 	Pts in diverse set:  209
# 	Pts in remaining set:  6165
# 3207
# Selecting point  209
# 	Selected point  1392
# 	Pts in diverse set:  210
# 	Pts in remaining set:  6164
# 3476
# Selecting point  210
# 	Selected point  5473
# 	Pts in diverse set:  211
# 	Pts in remaining set:  6163
# 1392
# Selecting point  211
# 	Selected point  392
# 	Pts in diverse set:  212
# 	Pts in remaining set:  6162
# 5473
# Selecting point  212
# 	Selected point  2463
# 	Pts in diverse set:  213
# 	Pts in remaining set:  6161
# 392
# Selecting point  213
# 	Selected point  5031
# 	Pts in diverse set:  214
# 	Pts in remaining set:  6160
# 2463
# Selecting point  214
# 	Selected point  362
# 	Pts in diverse set:  215
# 	Pts in remaining set:  6159
# 5031
# Selecting point  215
# 	Selected point  1579
# 	Pts in diverse set:  216
# 	Pts in remaining set:  6158
# 362
# Selecting point  216
# 	Selected point  5556
# 	Pts in diverse set:  217
# 	Pts in remaining set:  6157
# 1579
# Selecting point  217
# 	Selected point  1600
# 	Pts in diverse set:  218
# 	Pts in remaining set:  6156
# 5556
# Selecting point  218
# 	Selected point  2698
# 	Pts in diverse set:  219
# 	Pts in remaining set:  6155
# 1600
# Selecting point  219
# 	Selected point  2195
# 	Pts in diverse set:  220
# 	Pts in remaining set:  6154
# 2698
# Selecting point  220
# 	Selected point  2840
# 	Pts in diverse set:  221
# 	Pts in remaining set:  6153
# 2195
# Selecting point  221
# 	Selected point  252
# 	Pts in diverse set:  222
# 	Pts in remaining set:  6152
# 2840
# Selecting point  222
# 	Selected point  5577
# 	Pts in diverse set:  223
# 	Pts in remaining set:  6151
# 252
# Selecting point  223
# 	Selected point  6119
# 	Pts in diverse set:  224
# 	Pts in remaining set:  6150
# 5577
# Selecting point  224
# 	Selected point  3054
# 	Pts in diverse set:  225
# 	Pts in remaining set:  6149
# 6119
# Selecting point  225
# 	Selected point  2432
# 	Pts in diverse set:  226
# 	Pts in remaining set:  6148
# 3054
# Selecting point  226
# 	Selected point  3638
# 	Pts in diverse set:  227
# 	Pts in remaining set:  6147
# 2432
# Selecting point  227
# 	Selected point  3561
# 	Pts in diverse set:  228
# 	Pts in remaining set:  6146
# 3638
# Selecting point  228
# 	Selected point  1329
# 	Pts in diverse set:  229
# 	Pts in remaining set:  6145
# 3561
# Selecting point  229
# 	Selected point  2150
# 	Pts in diverse set:  230
# 	Pts in remaining set:  6144
# 1329
# Selecting point  230
# 	Selected point  4645
# 	Pts in diverse set:  231
# 	Pts in remaining set:  6143
# 2150
# Selecting point  231
# 	Selected point  2279
# 	Pts in diverse set:  232
# 	Pts in remaining set:  6142
# 4645
# Selecting point  232
# 	Selected point  5932
# 	Pts in diverse set:  233
# 	Pts in remaining set:  6141
# 2279
# Selecting point  233
# 	Selected point  471
# 	Pts in diverse set:  234
# 	Pts in remaining set:  6140
# 5932
# Selecting point  234
# 	Selected point  4457
# 	Pts in diverse set:  235
# 	Pts in remaining set:  6139
# 471
# Selecting point  235
# 	Selected point  2449
# 	Pts in diverse set:  236
# 	Pts in remaining set:  6138
# 4457
# Selecting point  236
# 	Selected point  2498
# 	Pts in diverse set:  237
# 	Pts in remaining set:  6137
# 2449
# Selecting point  237
# 	Selected point  4371
# 	Pts in diverse set:  238
# 	Pts in remaining set:  6136
# 2498
# Selecting point  238
# 	Selected point  4120
# 	Pts in diverse set:  239
# 	Pts in remaining set:  6135
# 4371
# Selecting point  239
# 	Selected point  1056
# 	Pts in diverse set:  240
# 	Pts in remaining set:  6134
# 4120
# Selecting point  240
# 	Selected point  227
# 	Pts in diverse set:  241
# 	Pts in remaining set:  6133
# 1056
# Selecting point  241
# 	Selected point  1661
# 	Pts in diverse set:  242
# 	Pts in remaining set:  6132
# 227
# Selecting point  242
# 	Selected point  2802
# 	Pts in diverse set:  243
# 	Pts in remaining set:  6131
# 1661
# Selecting point  243
# 	Selected point  5992
# 	Pts in diverse set:  244
# 	Pts in remaining set:  6130
# 2802
# Selecting point  244
# 	Selected point  520
# 	Pts in diverse set:  245
# 	Pts in remaining set:  6129
# 5992
# Selecting point  245
# 	Selected point  1683
# 	Pts in diverse set:  246
# 	Pts in remaining set:  6128
# 520
# Selecting point  246
# 	Selected point  315
# 	Pts in diverse set:  247
# 	Pts in remaining set:  6127
# 1683
# Selecting point  247
# 	Selected point  3294
# 	Pts in diverse set:  248
# 	Pts in remaining set:  6126
# 315
# Selecting point  248
# 	Selected point  5362
# 	Pts in diverse set:  249
# 	Pts in remaining set:  6125
# 3294
# Selecting point  249
# 	Selected point  4719
# 	Pts in diverse set:  250
# 	Pts in remaining set:  6124
# 5362
# Selecting point  250
# 	Selected point  2322
# 	Pts in diverse set:  251
# 	Pts in remaining set:  6123
# 4719
# Selecting point  251
# 	Selected point  1654
# 	Pts in diverse set:  252
# 	Pts in remaining set:  6122
# 2322
# Selecting point  252
# 	Selected point  4800
# 	Pts in diverse set:  253
# 	Pts in remaining set:  6121
# 1654
# Selecting point  253
# 	Selected point  891
# 	Pts in diverse set:  254
# 	Pts in remaining set:  6120
# 4800
# Selecting point  254
# 	Selected point  370
# 	Pts in diverse set:  255
# 	Pts in remaining set:  6119
# 891
# Selecting point  255
# 	Selected point  5923
# 	Pts in diverse set:  256
# 	Pts in remaining set:  6118
# 370
# Selecting point  256
# 	Selected point  423
# 	Pts in diverse set:  257
# 	Pts in remaining set:  6117
# 5923
# Selecting point  257
# 	Selected point  2128
# 	Pts in diverse set:  258
# 	Pts in remaining set:  6116
# 423
# Selecting point  258
# 	Selected point  4366
# 	Pts in diverse set:  259
# 	Pts in remaining set:  6115
# 2128
# Selecting point  259
# 	Selected point  5532
# 	Pts in diverse set:  260
# 	Pts in remaining set:  6114
# 4366
# Selecting point  260
# 	Selected point  5384
# 	Pts in diverse set:  261
# 5790
# Selecting point  316
# 	Selected point  1461
# 	Pts in diverse set:  317
# 	Pts in remaining set:  6057
# 4349
# Selecting point  317
# 	Selected point  4072
# 	Pts in diverse set:  318
# 	Pts in remaining set:  6056
# 1461
# Selecting point  318
# 	Selected point  3793
# 	Pts in diverse set:  319
# 	Pts in remaining set:  6055
# 4072
# Selecting point  319
# 	Selected point  1402
# 	Pts in diverse set:  320
# 	Pts in remaining set:  6054
# 3793
# Selecting point  320
# 	Selected point  2601
# 	Pts in diverse set:  321
# 	Pts in remaining set:  6053
# 1402
# Selecting point  321
# 	Selected point  3632
# 	Pts in diverse set:  322
# 	Pts in remaining set:  6052
# 2601
# Selecting point  322
# 	Selected point  5014
# 	Pts in diverse set:  323
# 	Pts in remaining set:  6051
# 3632
# Selecting point  323
# 	Selected point  1767
# 	Pts in diverse set:  324
# 	Pts in remaining set:  6050
# 5014
# Selecting point  324
# 	Selected point  5229
# 	Pts in diverse set:  325
# 	Pts in remaining set:  6049
# 1767
# Selecting point  325
# 	Selected point  3884
# 	Pts in diverse set:  326
# 	Pts in remaining set:  6048
# 5229
# Selecting point  326
# 	Selected point  1997
# 	Pts in diverse set:  327
# 	Pts in remaining set:  6047
# 3884
# Selecting point  327
# 	Selected point  4369
# 	Pts in diverse set:  328
# 	Pts in remaining set:  6046
# 1997
# Selecting point  328
# 	Selected point  710
# 	Pts in diverse set:  329
# 	Pts in remaining set:  6045
# 4369
# Selecting point  329
# 	Selected point  2640
# 	Pts in diverse set:  330
# 	Pts in remaining set:  6044
# 710
# Selecting point  330
# 	Selected point  2637
# 	Pts in diverse set:  331
# 	Pts in remaining set:  6043
# 2640
# Selecting point  331
# 	Selected point  5039
# 	Pts in diverse set:  332
# 	Pts in remaining set:  6042
# 2637
# Selecting point  332
# 	Selected point  832
# 	Pts in diverse set:  333
# 	Pts in remaining set:  6041
# 5039
# Selecting point  333
# 	Selected point  3593
# 	Pts in diverse set:  334
# 	Pts in remaining set:  6040
# 832
# Selecting point  334
# 	Selected point  4875
# 	Pts in diverse set:  335
# 	Pts in remaining set:  6039
# 3593
# Selecting point  335
# 	Selected point  3373
# 	Pts in diverse set:  336
# 	Pts in remaining set:  6038
# 4875
# Selecting point  336
# 	Selected point  5147
# 	Pts in diverse set:  337
# 	Pts in remaining set:  6037
# 3373
# Selecting point  337
# 	Selected point  4426
# 	Pts in diverse set:  338
# 	Pts in remaining set:  6036
# 5147
# Selecting point  338
# 	Selected point  613
# 	Pts in diverse set:  339
# 	Pts in remaining set:  6035
# 4426
# Selecting point  339
# 	Selected point  1797
# 	Pts in diverse set:  340
# 	Pts in remaining set:  6034
# 613
# Selecting point  340
# 	Selected point  1819
# 	Pts in diverse set:  341
# 	Pts in remaining set:  6033
# 1797
# Selecting point  341
# 	Selected point  2041
# 	Pts in diverse set:  342
# 	Pts in remaining set:  6032
# 1819
# Selecting point  342
# 	Selected point  344
# 	Pts in diverse set:  343
# 	Pts in remaining set:  6031
# 2041
# Selecting point  343
# 	Selected point  4178
# 	Pts in diverse set:  344
# 	Selected point  1595
# 	Pts in diverse set:  5096
# 	Pts in remaining set:  1278
# 761
# Selecting point  5096
# 	Selected point  4250
# 	Pts in diverse set:  5097
# 	Pts in remaining set:  1277
# 1595
# Selecting point  5097
# 	Selected point  3579
# 	Pts in diverse set:  5098
# 	Pts in remaining set:  1276
# 4250
# Selecting point  5098
# 	Selected point  5501
# 	Pts in diverse set:  5099
# 	Pts in remaining set:  1275
# 3579
# Save file name : divided_set_0.8_0.2_6_Methane_merge_AGSAfeature.txt

# %% [markdown]
# ## 2.2 Load divided dataset

# %%
diverse_set=[]
remaining_set=[]
txt = open("divided_set_"+str(diverse_ratio)+"_"+str("%.1f" %(remaining_ratio))+"_"+str(feature_num)+"_"+file_name+"feature.txt",'r').read()
print(" Load file name : divided_set_"+str(diverse_ratio)+"_"+str("%.1f" %(remaining_ratio))+"_"+str(feature_num)+"_"+file_name+"feature.txt")
s1=txt.find("[",0)
s2=txt.find("]",s1)
diverse_set=txt[s1+1:s2].split(", ")
diverse_set=[int(i) for i in diverse_set]
s3=txt.find("[",s2)
s4=txt.find("]",s3)
remaining_set=txt[s3+1:s4].split(", ")
remaining_set=[int(i) for i in remaining_set]
print("# of diverse set, remaining set :",len(diverse_set),len(remaining_set))

with open(data_file_name) as f:
    data_file = csv.reader(f)
    temp = next(data_file)
    N_samples = int(temp[0])
    N_features = int(temp[1])
    if N_features != feature_num:
        print("N_features is not"+str(feature_num))
        sys.exit()
    data = np.empty((N_samples, N_features))
    temp = next(data_file) 
    feature_list=temp[:N_features]
    for i, d in enumerate(data_file):
        data[i] = np.asarray(d[:N_features], dtype=np.float64)
    
N_materials = data.shape[0]
X_train = data[diverse_set]
X_test = data[remaining_set]
# Out:
#  Load file name : divided_set_0.8_0.2_6_Methane_merge_AGSAfeature.txt
# # of diverse set, remaining set : 5099 1275

# %%
# Out:
# (5099, 6)

# %% [markdown]
# ## 2.3 Plot feature distribution

# %%
feature_0 = data.T[0]
feature_1 = data.T[1]
feature_2 = data.T[2]
feature_3 = data.T[3]
feature_4 = data.T[4]
feature_5 = data.T[5]
# rescale
feature_0 = (feature_0 - np.min(feature_0))/(np.max(feature_0) - np.min(feature_0))
feature_1 = (feature_1 - np.min(feature_1))/(np.max(feature_1) - np.min(feature_1))
feature_2 = (feature_2 - np.min(feature_2))/(np.max(feature_2) - np.min(feature_2))
feature_3 = (feature_3 - np.min(feature_3))/(np.max(feature_3) - np.min(feature_3))
feature_4 = (feature_4 - np.min(feature_4))/(np.max(feature_4) - np.min(feature_4))
feature_5 = (feature_5 - np.min(feature_5))/(np.max(feature_5) - np.min(feature_5))
if N_features == 5:
    x = np.concatenate((feature_0.reshape(1,N_materials),feature_1.reshape(1,N_materials),feature_2.reshape(1,N_materials),feature_3.reshape(1,N_materials),feature_4.reshape(1,N_materials)))
if N_features == 6:
    x = np.concatenate((feature_0.reshape(1,N_materials),feature_1.reshape(1,N_materials),feature_2.reshape(1,N_materials),feature_3.reshape(1,N_materials),feature_4.reshape(1,N_materials),feature_5.reshape(1,N_materials)))
if N_features == 7:
    x = np.concatenate((feature_0.reshape(1,N_materials),feature_1.reshape(1,N_materials),feature_2.reshape(1,N_materials),feature_3.reshape(1,N_materials),feature_4.reshape(1,N_materials),feature_5.reshape(1,N_materials),feature_6.reshape(1,N_materials)))
data=x.T
   
X_train = data[diverse_set]
X_test = data[remaining_set]

feature_list=['LCD', 'PLD', 'AGSA','$\mathit{\u03C1}$',  'Void Fraction',r'$\Delta\mathit{H}_{\mathrm{ads,298}}$$_{ }$$_{ }$$_{ }$$_\mathrm{ K}$']
fig=plt.figure(figsize=(12,19))
for i in range(feature_num):
    ax=plt.subplot(math.ceil(feature_num/2),2,i+1)
    if i%2==0:
        ax.set_ylabel("Probability density",fontsize=17)
    if i > 3 :
        ax.set_xlabel("Nomalization value",fontsize=17)
    ax.set_title(feature_list[i],fontsize=20,position=(.5,1.01))
    #for axis in ['top','bottom','left','right']:
    #ax.spines[axis].set_linewidth(2)
    ax.tick_params(axis='both', which='both', direction='in', labelsize=15)
    sns.distplot(list(X_train.T[i]),ax=ax, color='b',label="Training",hist=False,bins='scott',norm_hist=True, kde_kws={"shade": True})
    sns.distplot(list(X_test.T[i]),ax=ax, color='r',label="Test",hist=False,bins='scott',norm_hist=True, kde_kws={"shade": True})
    plt.legend(frameon=True,fontsize=13,edgecolor='k',loc='best')
plt.tight_layout()
plt.savefig("feature_distribution"+"_"+str(feature_num)+"_"+str(diverse_ratio)+"_"+str("%.1f"%remaining_ratio)+"_"+file_name+"_.png",dpi=400)
# Out:
# C:\Users\Anivia\Anaconda3\envs\Test_main\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Anivia\Anaconda3\envs\Test_main\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Anivia\Anaconda3\envs\Test_main\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Anivia\Anaconda3\envs\Test_main\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Anivia\Anaconda3\envs\Test_main\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Anivia\Anaconda3\envs\Test_main\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Anivia\Anaconda3\envs\Test_main\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Anivia\Anaconda3\envs\Test_main\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Anivia\Anaconda3\envs\Test_main\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Anivia\Anaconda3\envs\Test_main\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Anivia\Anaconda3\envs\Test_main\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Anivia\Anaconda3\envs\Test_main\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## 3.1 Train model(Gradient Boosting Regression)  and Save training model

# %%
importances_list=[]


for j,case in enumerate(cases):
    ### Load target ###
    with open(data_file_name) as f:
        data_file = csv.reader(f)
        temp = next(data_file)
        target = np.empty((N_samples,len(cases)))
        temp = next(data_file) 
        for i, d in enumerate(data_file):
            target[i] = np.asarray(d[feature_num:], dtype=np.float64)
    
    y_train = target[diverse_set].T
    y_test = target[remaining_set].T
    ### Hyperparameter tuning ###

    reg = GradientBoostingRegressor(max_features='sqrt',random_state=40)
    space  = [Integer(1,1000, name='n_estimators'),
            Integer(1, 5, name='max_depth'),
             Real(10**-5, 10**0, "log-uniform", name='learning_rate'),
             Integer(2, 100, name='min_samples_split'),
             Integer(1, 100, name='min_samples_leaf')]
    @use_named_args(space)
    
    def objective(**params):
        
        reg.set_params(**params)   
        
        return -np.mean(cross_val_score(reg, X_train, y_train[j], cv=5, n_jobs=-1,
                                            scoring="neg_mean_absolute_error"))
    
    res_gp = gp_minimize(objective, space, n_calls=100, random_state=40)
    
    print(case)
    print("Best score=%.4f" % res_gp.fun)
    print("""Best parameters:
        - n_estimator=%d
        - max_depth=%d
        - learning_rate=%.6f
        - min_samples_split=%d
        - min_samples_leaf=%d""" % (res_gp.x[0], res_gp.x[1],
                                    res_gp.x[2], res_gp.x[3],
                                    res_gp.x[4]))
    reg_opt = GradientBoostingRegressor(n_estimators=res_gp.x[0],
                                            max_depth=res_gp.x[1],
                                           learning_rate=res_gp.x[2],
                                           min_samples_split=res_gp.x[3],
                                           min_samples_leaf=res_gp.x[4],
                                           random_state=40,
                                           max_features='sqrt')
    reg_opt.fit(X_train, y_train[j])
    save_model = joblib.dump(reg_opt,"Methane_" + case + "_" + str(feature_num) + "_" + str(diverse_ratio) + "_" + str("%.1f"%remaining_ratio) +"_"+file_name+".pkl")
    print('R^2 Training Score: {:.3f} \nR^2 Testing Score: {:.3f}'.format(reg_opt.score(X_train, y_train[j]),reg_opt.score(X_test, y_test[j])))
    print('RMSE Training Score: {:.3f} \nRMSE Testing Score: {:.3f}'.format(np.sqrt(mean_squared_error(y_train[j],reg_opt.predict(X_train))),np.sqrt(mean_squared_error(y_test[j],reg_opt.predict(X_test)))))
    print('MAE Training Score: {:.3f} \nMAE Testing Score: {:.3f}'.format(mean_absolute_error(y_train[j],reg_opt.predict(X_train)),mean_absolute_error(y_test[j],reg_opt.predict(X_test))))
    print([feature+" : "+str(reg_opt.feature_importances_[i]) for i,feature in enumerate(feature_list)])
    importances_list.append(list(reg_opt.feature_importances_))
# Out:
# LNG_ANG
# Best score=16.2862
# Best parameters:
#         - n_estimator=1000
#         - max_depth=5
#         - learning_rate=0.019230
#         - min_samples_split=2
#         - min_samples_leaf=1
# R^2 Training Score: 0.977
# R^2 Testing Score: 0.969
# RMSE Training Score: 14.451
# RMSE Testing Score: 17.839
# MAE Training Score: 10.931
# MAE Testing Score: 12.796
# ['LCD : 0.12157379133902325', 'PLD : 0.020442802777412363', 'AGSA : 0.3038568325870519', 'Density : 0.12250764924509717', 'VF : 0.262255099167804', 'dH : 0.16936382488361135']
# ANG
# Best score=8.7603
# Best parameters:
#         - n_estimator=1000
#         - max_depth=5
#         - learning_rate=0.033962
#         - min_samples_split=2
#         - min_samples_leaf=1
# R^2 Training Score: 0.984
# R^2 Testing Score: 0.979
# RMSE Training Score: 6.338
# RMSE Testing Score: 7.805
# MAE Training Score: 4.875
# MAE Testing Score: 6.023
# ['LCD : 0.1305000195780682', 'PLD : 0.020474421268506626', 'AGSA : 0.36294660764262876', 'Density : 0.09872183948417916', 'VF : 0.22498856110005486', 'dH : 0.16236855092656233']
# 5bar
# Best score=10.1685
# Best parameters:
#         - n_estimator=871
#         - max_depth=5
#         - learning_rate=0.045033
#         - min_samples_split=2
#         - min_samples_leaf=1
# R^2 Training Score: 0.953
# R^2 Testing Score: 0.910
# RMSE Training Score: 6.858
# RMSE Testing Score: 8.785
# MAE Training Score: 5.114
# MAE Testing Score: 6.185
# ['LCD : 0.0978745783224394', 'PLD : 0.10769920822752697', 'AGSA : 0.17097924076449797', 'Density : 0.10065660060629683', 'VF : 0.11564122980263446', 'dH : 0.40714914227660437']
# 6bar
# Best score=16.7849
# Best parameters:
#         - n_estimator=996
#         - max_depth=5
#         - learning_rate=0.037356
#         - min_samples_split=2
#         - min_samples_leaf=1
# R^2 Training Score: 0.982
# R^2 Testing Score: 0.965
# RMSE Training Score: 11.642
# RMSE Testing Score: 16.922
# MAE Training Score: 8.858
# MAE Testing Score: 12.059
# ['LCD : 0.11360056498330932', 'PLD : 0.022549887269097506', 'AGSA : 0.45678574465689487', 'Density : 0.14016138710471324', 'VF : 0.21123003818457203', 'dH : 0.05567237780141294']
# 65bar
# Best score=12.8658
# Best parameters:
#         - n_estimator=1000
#         - max_depth=5
#         - learning_rate=0.052878
#         - min_samples_split=2
#         - min_samples_leaf=1
# R^2 Training Score: 0.977
# R^2 Testing Score: 0.951
# RMSE Training Score: 7.317
# RMSE Testing Score: 10.774
# MAE Training Score: 5.613
# MAE Testing Score: 8.053
# ['LCD : 0.09211474636998239', 'PLD : 0.044835593931707995', 'AGSA : 0.5167636181629931', 'Density : 0.12577553511240563', 'VF : 0.1545521991781847', 'dH : 0.06595830724472625']

# %% [markdown]
# ## 3.2 Load feature importance from saved model

# %%
importances_list=[]
for case in cases:
    reg_opt= joblib.load("Methane_" + case + "_" + str(feature_num) + "_" + str(diverse_ratio) + "_" + str("%.1f"%remaining_ratio) +"_"+file_name+".pkl") 
    importances_list.append(list(reg_opt.feature_importances_))
print("Complete!")
# Out:
# C:\Users\Anivia\Anaconda3\envs\Test_main\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.ensemble.gradient_boosting module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\Users\Anivia\Anaconda3\envs\Test_main\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.tree.tree module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.tree. Anything that cannot be imported from sklearn.tree is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\Users\Anivia\Anaconda3\envs\Test_main\lib\site-packages\sklearn\base.py:313: UserWarning: Trying to unpickle estimator DecisionTreeRegressor from version 0.20.3 when using version 0.22. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\Anivia\Anaconda3\envs\Test_main\lib\site-packages\sklearn\base.py:313: UserWarning: Trying to unpickle estimator GradientBoostingRegressor from version 0.20.3 when using version 0.22. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# Complete!

# %% [markdown]
# ## 3.3 Plot feature importances

# %%
#6features
importances_list = [importances_list[3],importances_list[4],importances_list[2],importances_list[0],importances_list[1]]
titles=['6 bar / 159 K','65 bar / 298 K','5 bar / 298 K','6 bar / 159 K → 5 bar / 298 K\n(LNG - ANG)             ','65 bar / 298 K → 5 bar / 298 K\n(ANG)                  ']
features_6 = ['LCD', 'PLD',  'AGSA','$\mathit{\u03C1}$', 'VF',r'$\Delta\mathit{H}_{\mathrm{ads,298}}$$_{ }$$_{ }$$_{ }$$_\mathrm{ K}$']
color_map='Set2_r'
fig, ax = plt.subplots(figsize=(14.4,6))

ax.invert_yaxis()
ax.set_xticks([])
ax.tick_params(axis='x', which='both', direction='out',width=0)
category_colors = plt.get_cmap(color_map)(np.linspace(0.1,0.9,feature_num))
importances_list_remake=np.array(importances_list)
ax.set_xlim(0, np.sum(importances_list_remake, axis=1).max())
ax.set_xlabel("Relative Importance (%)",size=18)
for i ,(feature,color) in enumerate(zip(features_6,category_colors)):
    widths = importances_list_remake[:,i]
    starts = importances_list_remake.cumsum(axis=1)[:,i] - widths
    ax.barh(titles,importances_list_remake[:,i],left=starts, height =0.5,
        label=feature,color=color)
    xcenters = starts + widths / 2 - 0.011
    g,r,b,_=color
    text_color='k'
    for y,(x,c) in enumerate(zip(xcenters,widths)):
        ax.text(x,y,str(round(float(c*100))),ha='left',va='center',color=text_color,fontsize=15)    
    ax.legend(ncol=len(features_6),bbox_to_anchor=(0,1),
                loc='lower left', fontsize=18)
ax.tick_params(direction='out',labelsize=16)
plt.tight_layout()
plt.savefig('./GBR_'+str(diverse_ratio)+'_'+str("%.1f"%remaining_ratio)+'_'+str(feature_num)+'feature_'+file_name+'.png',dpi=600)
plt.show()
